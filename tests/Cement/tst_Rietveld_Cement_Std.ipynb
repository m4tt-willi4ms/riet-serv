# %% [markdown]
# # Rietveld Playground: Cement
#
# This notebook calls the Rietveld refinement cement test, which runs a set of minimization routines to fit a profile consisting of the following eight phases:

# %%
# %load -r 139:149 tst_Rietveld_Cement.py
cifs = [
   "1540705-Alite.cif", 
   "9012789-Belite.cif", 
   "1200009-Ferrite.cif", 
   "1000039-AluminateCubic.cif", 
   "9014308-AluminateOrtho.cif", 
   "9007569-Arcanite.cif",
   "1011094-FreeLime.cif", 
   "1000053-Periclase.cif", 
   ]

# %% [markdown]
# The minimization routines are applied in the following order:
#
# * RR.minimize_Bkgd
#
#
# * RR.minimize_Amplitude_Offset
# * RR.minimize_unit_cell
# * RR.minimize_Amplitude_Bkgd_Offset_W
#
#
# * RR.minimize_All
#
# Before running each round of refinement, a list of the parameters to be refined is printed. During refinement, a period \(`.`\) is printed after each iteration. Finally once complete, a plot of the resulting fit is displayed, along with the updated parameters, the time taken to refine, and some fitting metrics.

# %%
# %matplotlib notebook
# %cd ../..
# %pylab inline
# pylab.rcParams['figure.figsize'] = (8,6)
# %run tests/Cement/tst_Rietveld_Cement_Std
# Out:
# C:\cctbx\CCTBX_Projects\Rietveld_Refinement
# cifs:
#
# 1540705-Alite.cif
# 1000039-AluminateCubic.cif
# 9014308-AluminateOrtho.cif
# 9004096-anhydrite.cif
# 9007569-Arcanite.cif
# 9005521-bassanite.cif
# 9012789-Belite.cif
# 9009667-calcite.cif
# 1200009-Ferrite.cif
# 1011094-FreeLime.cif
# 1000053-Periclase.cif
# 9000113-portlandite.cif
# <img src="data:image/png;base64,..." width="600">
# bkgd_0 = 0.0 (-inf, inf)
# bkgd_1 = 0.0 (-inf, inf)
# bkgd_2 = 0.0 (-inf, inf)
# ...........
#
# After minimize_bkgd:
# bkgd_0 = 66.1810053285 (-inf, inf)
# bkgd_1 = -2.03344128344 (-inf, inf)
# bkgd_2 = 0.0167596125313 (-inf, inf)
#
# Time taken to run minimize_bkgd: 0.86 seconds
# R_wp: 0.792583832256
# R_e: 0.0236152207486
# Goodness-of-Fit: 33.562414711
# <img src="data:image/png;base64,..." width="600">
# two_theta_0 = 0.0 (-0.2, 0.2)
# bkgd_0 = 66.1810053285 (-inf, inf)
# bkgd_1 = -2.03344128344 (-inf, inf)
# bkgd_2 = 0.0167596125313 (-inf, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# Amplitude = 9.96545880154 (0.0, inf)
# ...................................................................................................
#
# After minimize_Amplitude_Bkgd_Offset:
# two_theta_0 = -0.0818758045367 (-0.2, 0.2)
# bkgd_0 = 66.2091198175 (-inf, inf)
# bkgd_1 = -1.38664583473 (-inf, inf)
# bkgd_2 = 0.00794383348447 (-inf, inf)
# Amplitude = 19.6152490056 (0.0, inf)
# Amplitude = 1.15128256798 (0.0, inf)
# Amplitude = 1.86110615185 (0.0, inf)
# Amplitude = 0.492503514279 (0.0, inf)
# Amplitude = 2.23516065961 (0.0, inf)
# Amplitude = 0.305070791738 (0.0, inf)
# Amplitude = 6.22494342334 (0.0, inf)
# Amplitude = 4.57458650306 (0.0, inf)
# Amplitude = 1.4590916971 (0.0, inf)
# Amplitude = 0.0993677011223 (0.0, inf)
# Amplitude = 0.229649956687 (0.0, inf)
# Amplitude = 0.33135059795 (0.0, inf)
#
# Time taken to run minimize_Amplitude_Bkgd_Offset: 21.785 seconds
# R_wp: 0.144646443271
# R_e: 0.0235520978086
# Goodness-of-Fit: 6.14155241911
#
#
# Phase 1: 50.8438908752 %
# Phase 2: 2.98419282039 %
# Phase 3: 4.82409772443 %
# Phase 4: 1.27659837143 %
# Phase 5: 5.79366923322 %
# Phase 6: 0.790761618164 %
# Phase 7: 16.1354232124 %
# Phase 8: 11.857600018 %
# Phase 9: 3.78205237175 %
# Phase 10: 0.257566985305 %
# Phase 11: 0.595266332535 %
# Phase 12: 0.858880437298 %
#
# By weight:
# Phase 1: 51.670406235 %
# Phase 2: 2.90109683106 %
# Phase 3: 4.69115259165 %
# Phase 4: 1.21307504144 %
# Phase 5: 4.9612057633 %
# Phase 6: 1.09176422003 %
# Phase 7: 17.1129734649 %
# Phase 8: 10.3087094451 %
# Phase 9: 4.47232606745 %
# Phase 10: 0.27639451948 %
# Phase 11: 0.682150171959 %
# Phase 12: 0.618745648526 %
# <img src="data:image/png;base64,..." width="600">
# two_theta_0 = -0.0818758045367 (-0.2, 0.2)
# bkgd_0 = 66.2091198175 (-inf, inf)
# bkgd_1 = -1.38664583473 (-inf, inf)
# bkgd_2 = 0.00794383348447 (-inf, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 19.6152490056 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 1.15128256798 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 1.86110615185 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 0.492503514279 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 2.23516065961 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 0.305070791738 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 6.22494342334 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 4.57458650306 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 1.4590916971 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 0.0993677011223 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 0.229649956687 (0.0, inf)
# W = 0.001 (0.0001, 1.0)
# Amplitude = 0.33135059795 (0.0, inf)
# .......................................................................................................................................................
#
# After minimize_Amplitude_Bkgd_Offset_W:
# two_theta_0 = -0.0931500960892 (-0.2, 0.2)
# bkgd_0 = 66.4168976528 (-inf, inf)
# bkgd_1 = -1.46676784327 (-inf, inf)
# bkgd_2 = 0.00897309484749 (-inf, inf)
# W = 0.00189416998188 (0.0001, 1.0)
# Amplitude = 19.1437112545 (0.0, inf)
# W = 0.0425055102999 (0.0001, 1.0)
# Amplitude = 0.339101055316 (0.0, inf)
# W = 0.0009010959976 (0.0001, 1.0)
# Amplitude = 1.75152067633 (0.0, inf)
# W = 0.00685698057214 (0.0001, 1.0)
# Amplitude = 1.31114873415 (0.0, inf)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 2.14329112082 (0.0, inf)
# W = 0.986571515822 (0.0001, 1.0)
# Amplitude = 0.135741345878 (0.0, inf)
# W = 0.00125902385799 (0.0001, 1.0)
# Amplitude = 5.9996721552 (0.0, inf)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 4.34101465174 (0.0, inf)
# W = 0.0200027529337 (0.0001, 1.0)
# Amplitude = 0.965256420617 (0.0, inf)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.0819960677444 (0.0, inf)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.204323262644 (0.0, inf)
# W = 0.0662584968737 (0.0001, 1.0)
# Amplitude = 0.100195463791 (0.0, inf)
#
# Time taken to run minimize_Amplitude_Bkgd_Offset_W: 51.332 seconds
# R_wp: 0.118856855948
# R_e: 0.0234936799481
# Goodness-of-Fit: 5.0590991369
#
#
# Phase 1: 52.4241471748 %
# Phase 2: 0.928612189909 %
# Phase 3: 4.79645647048 %
# Phase 4: 3.59051875018 %
# Phase 5: 5.86930128974 %
# Phase 6: 0.37172125088 %
# Phase 7: 16.4298182251 %
# Phase 8: 11.8876631582 %
# Phase 9: 2.64330902108 %
# Phase 10: 0.224542350543 %
# Phase 11: 0.559529583878 %
# Phase 12: 0.274380535217 %
#
# By weight:
# Phase 1: 53.4045017626 %
# Phase 2: 0.904926110201 %
# Phase 3: 4.67549251007 %
# Phase 4: 3.42006197316 %
# Phase 5: 5.03806007139 %
# Phase 6: 0.51445105376 %
# Phase 7: 17.4671186377 %
# Phase 8: 10.3597049958 %
# Phase 9: 3.13326591736 %
# Phase 10: 0.241535456488 %
# Phase 11: 0.642739694555 %
# Phase 12: 0.198141816924 %
# <img src="data:image/png;base64,..." width="600">
# two_theta_0 = -0.0931500960892 (-0.2, 0.2)
# bkgd_0 = 66.4168976528 (-inf, inf)
# bkgd_1 = -1.46676784327 (-inf, inf)
# bkgd_2 = 0.00897309484749 (-inf, inf)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.00189416998188 (0.0001, 1.0)
# Amplitude = 19.1437112545 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 33.1078 (32.776722, 33.438878)
# uc_b = 7.0355 (6.965145, 7.105855)
# uc_c = 18.5211 (18.335889, 18.706311)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.137 (93.19563, 95.07837)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0425055102999 (0.0001, 1.0)
# Amplitude = 0.339101055316 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 15.263 (15.11037, 15.41563)
# uc_b = 15.263 (15.11037, 15.41563)
# uc_c = 15.263 (15.11037, 15.41563)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0009010959976 (0.0001, 1.0)
# Amplitude = 1.75152067633 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 10.875 (10.76625, 10.98375)
# uc_b = 10.859 (10.75041, 10.96759)
# uc_c = 15.105 (14.95395, 15.25605)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.00685698057214 (0.0001, 1.0)
# Amplitude = 1.31114873415 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 6.993 (6.92307, 7.06293)
# uc_b = 6.995 (6.92505, 7.06495)
# uc_c = 6.245 (6.18255, 6.30745)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 2.14329112082 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 7.476 (7.40124, 7.55076)
# uc_b = 10.071 (9.97029, 10.17171)
# uc_c = 5.763 (5.70537, 5.82063)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.986571515822 (0.0001, 1.0)
# Amplitude = 0.135741345878 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 12.035 (11.91465, 12.15535)
# uc_b = 6.9294 (6.860106, 6.998694)
# uc_c = 12.6705 (12.543795, 12.797205)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.266 (89.36334, 91.16866)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.00125902385799 (0.0001, 1.0)
# Amplitude = 5.9996721552 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 5.5041 (5.449059, 5.559141)
# uc_b = 6.7622 (6.694578, 6.829822)
# uc_c = 9.3281 (9.234819, 9.421381)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.172 (93.23028, 95.11372)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 4.34101465174 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 4.991 (4.94109, 5.04091)
# uc_b = 4.991 (4.94109, 5.04091)
# uc_c = 17.068 (16.89732, 17.23868)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0200027529337 (0.0001, 1.0)
# Amplitude = 0.965256420617 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 5.584 (5.52816, 5.63984)
# uc_b = 14.6 (14.454, 14.746)
# uc_c = 5.374 (5.32026, 5.42774)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.0819960677444 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 4.812 (4.76388, 4.86012)
# uc_b = 4.812 (4.76388, 4.86012)
# uc_c = 4.812 (4.76388, 4.86012)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.204323262644 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 4.217 (4.17483, 4.25917)
# uc_b = 4.217 (4.17483, 4.25917)
# uc_c = 4.217 (4.17483, 4.25917)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -0.0 (-0.1, 0.0)
# W = 0.0662584968737 (0.0001, 1.0)
# Amplitude = 0.100195463791 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (-0.001, 0.001)
# uc_a = 3.5925 (3.556575, 3.628425)
# uc_b = 3.5925 (3.556575, 3.628425)
# uc_c = 4.905 (4.85595, 4.95405)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
# ...........
#
# After minimize_All:
# two_theta_0 = -0.0931523116276 (-0.2, 0.2)
# bkgd_0 = 66.4168981184 (-inf, inf)
# bkgd_1 = -1.46676660096 (-inf, inf)
# bkgd_2 = 0.00897748780539 (-inf, inf)
# U = 0.0 (0.0, 0.1)
# V = -0.000480420133545 (-0.1, 0.0)
# W = 0.00202005891471 (0.0001, 1.0)
# Amplitude = 19.1437103946 (0.0, inf)
# eta_0 = 0.500000079523 (0.0, 1.0)
# eta_1 = -2.93248598062e-05 (-0.001, 0.001)
# uc_a = 33.1078 (32.776722, 33.438878)
# uc_b = 7.0355 (6.965145, 7.105855)
# uc_c = 18.5211 (18.335889, 18.706311)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.137 (93.19563, 95.07837)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 1.25932489286e-07 (0.0, 0.1)
# V = 0.0 (-0.1, 0.0)
# W = 0.0425063710109 (0.0001, 1.0)
# Amplitude = 0.339102530403 (0.0, inf)
# eta_0 = 0.499999953548 (0.0, 1.0)
# eta_1 = -1.838943943e-06 (-0.001, 0.001)
# uc_a = 15.263 (15.11037, 15.41563)
# uc_b = 15.263 (15.11037, 15.41563)
# uc_c = 15.263 (15.11037, 15.41563)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -8.64431371453e-06 (-0.1, 0.0)
# W = 0.000909882145345 (0.0001, 1.0)
# Amplitude = 1.75152040515 (0.0, inf)
# eta_0 = 0.500000111803 (0.0, 1.0)
# eta_1 = 4.32964177211e-06 (-0.001, 0.001)
# uc_a = 10.875 (10.76625, 10.98375)
# uc_b = 10.859 (10.75041, 10.96759)
# uc_c = 15.105 (14.95395, 15.25605)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -1.71881468867e-05 (-0.1, 0.0)
# W = 0.00685860955265 (0.0001, 1.0)
# Amplitude = 1.31114851326 (0.0, inf)
# eta_0 = 0.500000102626 (0.0, 1.0)
# eta_1 = -2.4398499103e-06 (-0.001, 0.001)
# uc_a = 6.993 (6.92307, 7.06293)
# uc_b = 6.995 (6.92505, 7.06495)
# uc_c = 6.245 (6.18255, 6.30745)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 7.65625214257e-06 (0.0, 0.1)
# V = -4.15598406885e-05 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 2.14329097328 (0.0, inf)
# eta_0 = 0.500000058916 (0.0, 1.0)
# eta_1 = 2.03388996108e-06 (-0.001, 0.001)
# uc_a = 7.476 (7.40124, 7.55076)
# uc_b = 10.071 (9.97029, 10.17171)
# uc_c = 5.763 (5.70537, 5.82063)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -4.71773461662e-09 (-0.1, 0.0)
# W = 0.986571530106 (0.0001, 1.0)
# Amplitude = 0.135744903014 (0.0, inf)
# eta_0 = 0.499999994062 (0.0, 1.0)
# eta_1 = 1.04064447003e-07 (-0.001, 0.001)
# uc_a = 12.035 (11.91465, 12.15535)
# uc_b = 6.9294 (6.860106, 6.998694)
# uc_c = 12.6705 (12.543795, 12.797205)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.266 (89.36334, 91.16866)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -3.75825245124e-05 (-0.1, 0.0)
# W = 0.00127785931936 (0.0001, 1.0)
# Amplitude = 5.99967175211 (0.0, inf)
# eta_0 = 0.500000250413 (0.0, 1.0)
# eta_1 = 7.41036305404e-06 (-0.001, 0.001)
# uc_a = 5.5041 (5.449059, 5.559141)
# uc_b = 6.7622 (6.694578, 6.829822)
# uc_c = 9.3281 (9.234819, 9.421381)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.172 (93.23028, 95.11372)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 7.30429022418e-05 (0.0, 0.1)
# V = -0.000521859602662 (-0.1, 0.0)
# W = 0.000173267661677 (0.0001, 1.0)
# Amplitude = 4.34101444827 (0.0, inf)
# eta_0 = 0.500000161175 (0.0, 1.0)
# eta_1 = 6.30728301152e-06 (-0.001, 0.001)
# uc_a = 4.991 (4.94109, 5.04091)
# uc_b = 4.991 (4.94109, 5.04091)
# uc_c = 17.068 (16.89732, 17.23868)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
# U = 0.0 (0.0, 0.1)
# V = -6.98979856193e-06 (-0.1, 0.0)
# W = 0.0199981152837 (0.0001, 1.0)
# Amplitude = 0.965254375112 (0.0, inf)
# eta_0 = 0.500000283113 (0.0, 1.0)
# eta_1 = 9.61707460551e-06 (-0.001, 0.001)
# uc_a = 5.584 (5.52816, 5.63984)
# uc_b = 14.6 (14.454, 14.746)
# uc_c = 5.374 (5.32026, 5.42774)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 3.4661860045e-06 (0.0, 0.1)
# V = -1.61109887671e-06 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.0819960452321 (0.0, inf)
# eta_0 = 0.500000003589 (0.0, 1.0)
# eta_1 = 1.73270841224e-07 (-0.001, 0.001)
# uc_a = 4.812 (4.76388, 4.86012)
# uc_b = 4.812 (4.76388, 4.86012)
# uc_c = 4.812 (4.76388, 4.86012)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 5.68314245573e-06 (0.0, 0.1)
# V = -6.55478807412e-06 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.204323182108 (0.0, inf)
# eta_0 = 0.500000007135 (0.0, 1.0)
# eta_1 = 4.78042426926e-07 (-0.001, 0.001)
# uc_a = 4.217 (4.17483, 4.25917)
# uc_b = 4.217 (4.17483, 4.25917)
# uc_c = 4.217 (4.17483, 4.25917)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -2.24683773648e-08 (-0.1, 0.0)
# W = 0.0662587630324 (0.0001, 1.0)
# Amplitude = 0.100195446672 (0.0, inf)
# eta_0 = 0.500000005924 (0.0, 1.0)
# eta_1 = 2.86886219557e-07 (-0.001, 0.001)
# uc_a = 3.5925 (3.556575, 3.628425)
# uc_b = 3.5925 (3.556575, 3.628425)
# uc_c = 4.905 (4.85595, 4.95405)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
#
# Time taken to run minimize_All: 12.778 seconds
# R_wp: 0.117046547087
# R_e: 0.0229013069649
# Goodness-of-Fit: 5.11091123606
#
#
# Phase 1: 52.4241437282 %
# Phase 2: 0.928616210028 %
# Phase 3: 4.796455628 %
# Phase 4: 3.5905180705 %
# Phase 5: 5.86930076349 %
# Phase 6: 0.371730984189 %
# Phase 7: 16.4298167791 %
# Phase 8: 11.8876623534 %
# Phase 9: 2.64330336451 %
# Phase 10: 0.224542284218 %
# Phase 11: 0.559529351682 %
# Phase 12: 0.274380482622 %
#
# By weight:
# Phase 1: 53.4044968433 %
# Phase 2: 0.904930003915 %
# Phase 3: 4.67549156554 %
# Phase 4: 3.42006123555 %
# Phase 5: 5.03805948682 %
# Phase 6: 0.5144645108 %
# Phase 7: 17.4671166398 %
# Phase 8: 10.3597040213 %
# Phase 9: 3.13325912968 %
# Phase 10: 0.241535378774 %
# Phase 11: 0.642739410878 %
# Phase 12: 0.198141773717 %
# <img src="data:image/png;base64,..." width="600">
# two_theta_0 = -0.0931523116276 (-0.2, 0.2)
# bkgd_0 = 66.4168981184 (-inf, inf)
# bkgd_1 = -1.46676660096 (-inf, inf)
# bkgd_2 = 0.00897748780539 (-inf, inf)
# U = 0.0 (0.0, 0.1)
# V = -0.000480420133545 (-0.1, 0.0)
# W = 0.00202005891471 (0.0001, 1.0)
# Amplitude = 19.1437103946 (0.0, inf)
# eta_0 = 0.500000079523 (0.0, 1.0)
# eta_1 = -2.93248598062e-05 (-0.001, 0.001)
# uc_a = 33.1078 (32.776722, 33.438878)
# uc_b = 7.0355 (6.965145, 7.105855)
# uc_c = 18.5211 (18.335889, 18.706311)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.137 (93.19563, 95.07837)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 1.25932489286e-07 (0.0, 0.1)
# V = 0.0 (-0.1, 0.0)
# W = 0.0425063710109 (0.0001, 1.0)
# Amplitude = 0.339102530403 (0.0, inf)
# eta_0 = 0.499999953548 (0.0, 1.0)
# eta_1 = -1.838943943e-06 (-0.001, 0.001)
# uc_a = 15.263 (15.11037, 15.41563)
# uc_b = 15.263 (15.11037, 15.41563)
# uc_c = 15.263 (15.11037, 15.41563)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -8.64431371453e-06 (-0.1, 0.0)
# W = 0.000909882145345 (0.0001, 1.0)
# Amplitude = 1.75152040515 (0.0, inf)
# eta_0 = 0.500000111803 (0.0, 1.0)
# eta_1 = 4.32964177211e-06 (-0.001, 0.001)
# uc_a = 10.875 (10.76625, 10.98375)
# uc_b = 10.859 (10.75041, 10.96759)
# uc_c = 15.105 (14.95395, 15.25605)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -1.71881468867e-05 (-0.1, 0.0)
# W = 0.00685860955265 (0.0001, 1.0)
# Amplitude = 1.31114851326 (0.0, inf)
# eta_0 = 0.500000102626 (0.0, 1.0)
# eta_1 = -2.4398499103e-06 (-0.001, 0.001)
# uc_a = 6.993 (6.92307, 7.06293)
# uc_b = 6.995 (6.92505, 7.06495)
# uc_c = 6.245 (6.18255, 6.30745)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 7.65625214257e-06 (0.0, 0.1)
# V = -4.15598406885e-05 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 2.14329097328 (0.0, inf)
# eta_0 = 0.500000058916 (0.0, 1.0)
# eta_1 = 2.03388996108e-06 (-0.001, 0.001)
# uc_a = 7.476 (7.40124, 7.55076)
# uc_b = 10.071 (9.97029, 10.17171)
# uc_c = 5.763 (5.70537, 5.82063)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -4.71773461662e-09 (-0.1, 0.0)
# W = 0.986571530106 (0.0001, 1.0)
# Amplitude = 0.135744903014 (0.0, inf)
# eta_0 = 0.499999994062 (0.0, 1.0)
# eta_1 = 1.04064447003e-07 (-0.001, 0.001)
# uc_a = 12.035 (11.91465, 12.15535)
# uc_b = 6.9294 (6.860106, 6.998694)
# uc_c = 12.6705 (12.543795, 12.797205)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.266 (89.36334, 91.16866)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -3.75825245124e-05 (-0.1, 0.0)
# W = 0.00127785931936 (0.0001, 1.0)
# Amplitude = 5.99967175211 (0.0, inf)
# eta_0 = 0.500000250413 (0.0, 1.0)
# eta_1 = 7.41036305404e-06 (-0.001, 0.001)
# uc_a = 5.5041 (5.449059, 5.559141)
# uc_b = 6.7622 (6.694578, 6.829822)
# uc_c = 9.3281 (9.234819, 9.421381)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.172 (93.23028, 95.11372)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 7.30429022418e-05 (0.0, 0.1)
# V = -0.000521859602662 (-0.1, 0.0)
# W = 0.000173267661677 (0.0001, 1.0)
# Amplitude = 4.34101444827 (0.0, inf)
# eta_0 = 0.500000161175 (0.0, 1.0)
# eta_1 = 6.30728301152e-06 (-0.001, 0.001)
# uc_a = 4.991 (4.94109, 5.04091)
# uc_b = 4.991 (4.94109, 5.04091)
# uc_c = 17.068 (16.89732, 17.23868)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
# U = 0.0 (0.0, 0.1)
# V = -6.98979856193e-06 (-0.1, 0.0)
# W = 0.0199981152837 (0.0001, 1.0)
# Amplitude = 0.965254375112 (0.0, inf)
# eta_0 = 0.500000283113 (0.0, 1.0)
# eta_1 = 9.61707460551e-06 (-0.001, 0.001)
# uc_a = 5.584 (5.52816, 5.63984)
# uc_b = 14.6 (14.454, 14.746)
# uc_c = 5.374 (5.32026, 5.42774)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 3.4661860045e-06 (0.0, 0.1)
# V = -1.61109887671e-06 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.0819960452321 (0.0, inf)
# eta_0 = 0.500000003589 (0.0, 1.0)
# eta_1 = 1.73270841224e-07 (-0.001, 0.001)
# uc_a = 4.812 (4.76388, 4.86012)
# uc_b = 4.812 (4.76388, 4.86012)
# uc_c = 4.812 (4.76388, 4.86012)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 5.68314245573e-06 (0.0, 0.1)
# V = -6.55478807412e-06 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.204323182108 (0.0, inf)
# eta_0 = 0.500000007135 (0.0, 1.0)
# eta_1 = 4.78042426926e-07 (-0.001, 0.001)
# uc_a = 4.217 (4.17483, 4.25917)
# uc_b = 4.217 (4.17483, 4.25917)
# uc_c = 4.217 (4.17483, 4.25917)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -2.24683773648e-08 (-0.1, 0.0)
# W = 0.0662587630324 (0.0001, 1.0)
# Amplitude = 0.100195446672 (0.0, inf)
# eta_0 = 0.500000005924 (0.0, 1.0)
# eta_1 = 2.86886219557e-07 (-0.001, 0.001)
# uc_a = 3.5925 (3.556575, 3.628425)
# uc_b = 3.5925 (3.556575, 3.628425)
# uc_c = 4.905 (4.85595, 4.95405)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
# ...........
#
# After minimize_All:
# two_theta_0 = -0.0931527267057 (-0.2, 0.2)
# bkgd_0 = 66.4168981451 (-inf, inf)
# bkgd_1 = -1.46676627399 (-inf, inf)
# bkgd_2 = 0.00899031331088 (-inf, inf)
# U = 0.0 (0.0, 0.1)
# V = -0.000486981470407 (-0.1, 0.0)
# W = 0.00204937207666 (0.0001, 1.0)
# Amplitude = 19.1437103689 (0.0, inf)
# eta_0 = 0.500000116077 (0.0, 1.0)
# eta_1 = -2.86669086989e-05 (-0.001, 0.001)
# uc_a = 33.1078 (32.776722, 33.438878)
# uc_b = 7.0355 (6.965145, 7.105855)
# uc_c = 18.5211 (18.335889, 18.706311)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.137 (93.19563, 95.07837)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 1.28539531247e-07 (0.0, 0.1)
# V = 0.0 (-0.1, 0.0)
# W = 0.0425064002902 (0.0001, 1.0)
# Amplitude = 0.339102596215 (0.0, inf)
# eta_0 = 0.499999951827 (0.0, 1.0)
# eta_1 = -1.90968221267e-06 (-0.001, 0.001)
# uc_a = 15.263 (15.11037, 15.41563)
# uc_b = 15.263 (15.11037, 15.41563)
# uc_c = 15.263 (15.11037, 15.41563)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -9.07853193633e-06 (-0.1, 0.0)
# W = 0.000910090400967 (0.0001, 1.0)
# Amplitude = 1.75152039488 (0.0, inf)
# eta_0 = 0.500000115997 (0.0, 1.0)
# eta_1 = 4.48688204326e-06 (-0.001, 0.001)
# uc_a = 10.875 (10.76625, 10.98375)
# uc_b = 10.859 (10.75041, 10.96759)
# uc_c = 15.105 (14.95395, 15.25605)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -1.77967051147e-05 (-0.1, 0.0)
# W = 0.0068587353495 (0.0001, 1.0)
# Amplitude = 1.31114850567 (0.0, inf)
# eta_0 = 0.500000106936 (0.0, 1.0)
# eta_1 = -2.51167970989e-06 (-0.001, 0.001)
# uc_a = 6.993 (6.92307, 7.06293)
# uc_b = 6.995 (6.92505, 7.06495)
# uc_c = 6.245 (6.18255, 6.30745)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 7.79079716054e-06 (0.0, 0.1)
# V = -4.34979042913e-05 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 2.143290968 (0.0, inf)
# eta_0 = 0.50000006108 (0.0, 1.0)
# eta_1 = 2.10568983384e-06 (-0.001, 0.001)
# uc_a = 7.476 (7.40124, 7.55076)
# uc_b = 10.071 (9.97029, 10.17171)
# uc_c = 5.763 (5.70537, 5.82063)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -4.84382592764e-09 (-0.1, 0.0)
# W = 0.986571530792 (0.0001, 1.0)
# Amplitude = 0.135745082962 (0.0, inf)
# eta_0 = 0.49999999382 (0.0, 1.0)
# eta_1 = 1.06764173832e-07 (-0.001, 0.001)
# uc_a = 12.035 (11.91465, 12.15535)
# uc_b = 6.9294 (6.860106, 6.998694)
# uc_c = 12.6705 (12.543795, 12.797205)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.266 (89.36334, 91.16866)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -3.82571390964e-05 (-0.1, 0.0)
# W = 0.00128062016014 (0.0001, 1.0)
# Amplitude = 5.99967173809 (0.0, inf)
# eta_0 = 0.500000261723 (0.0, 1.0)
# eta_1 = 7.76002439803e-06 (-0.001, 0.001)
# uc_a = 5.5041 (5.449059, 5.559141)
# uc_b = 6.7622 (6.694578, 6.829822)
# uc_c = 9.3281 (9.234819, 9.421381)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 94.172 (93.23028, 95.11372)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 8.05883444988e-05 (0.0, 0.1)
# V = -0.000512543176063 (-0.1, 0.0)
# W = 0.000171218911175 (0.0001, 1.0)
# Amplitude = 4.34101444358 (0.0, inf)
# eta_0 = 0.500000166454 (0.0, 1.0)
# eta_1 = 6.5240199525e-06 (-0.001, 0.001)
# uc_a = 4.991 (4.94109, 5.04091)
# uc_b = 4.991 (4.94109, 5.04091)
# uc_c = 17.068 (16.89732, 17.23868)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
# U = 0.0 (0.0, 0.1)
# V = -7.24843925498e-06 (-0.1, 0.0)
# W = 0.0199979577924 (0.0001, 1.0)
# Amplitude = 0.965254299688 (0.0, inf)
# eta_0 = 0.500000293845 (0.0, 1.0)
# eta_1 = 9.97528856051e-06 (-0.001, 0.001)
# uc_a = 5.584 (5.52816, 5.63984)
# uc_b = 14.6 (14.454, 14.746)
# uc_c = 5.374 (5.32026, 5.42774)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 3.59265789517e-06 (0.0, 0.1)
# V = -1.68368478389e-06 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.0819960443396 (0.0, inf)
# eta_0 = 0.500000003723 (0.0, 1.0)
# eta_1 = 1.79608681783e-07 (-0.001, 0.001)
# uc_a = 4.812 (4.76388, 4.86012)
# uc_b = 4.812 (4.76388, 4.86012)
# uc_c = 4.812 (4.76388, 4.86012)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 6.21357760166e-06 (0.0, 0.1)
# V = -6.27426835807e-06 (-0.1, 0.0)
# W = 0.0001 (0.0001, 1.0)
# Amplitude = 0.204323179827 (0.0, inf)
# eta_0 = 0.500000007467 (0.0, 1.0)
# eta_1 = 4.99864498339e-07 (-0.001, 0.001)
# uc_a = 4.217 (4.17483, 4.25917)
# uc_b = 4.217 (4.17483, 4.25917)
# uc_c = 4.217 (4.17483, 4.25917)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 90.0 (89.1, 90.9)
# U = 0.0 (0.0, 0.1)
# V = -2.22001757953e-08 (-0.1, 0.0)
# W = 0.0662587753997 (0.0001, 1.0)
# Amplitude = 0.100195453361 (0.0, inf)
# eta_0 = 0.500000006156 (0.0, 1.0)
# eta_1 = 2.9807319251e-07 (-0.001, 0.001)
# uc_a = 3.5925 (3.556575, 3.628425)
# uc_b = 3.5925 (3.556575, 3.628425)
# uc_c = 4.905 (4.85595, 4.95405)
# uc_alpha = 90.0 (89.1, 90.9)
# uc_beta = 90.0 (89.1, 90.9)
# uc_gamma = 120.0 (118.8, 121.2)
#
# Time taken to run minimize_All: 9.914 seconds
# R_wp: 0.116879074762
# R_e: 0.0229013069649
# Goodness-of-Fit: 5.10359845146
#
#
# Phase 1: 52.4241435053 %
# Phase 2: 0.928616387547 %
# Phase 3: 4.79645558589 %
# Phase 4: 3.59051803927 %
# Phase 5: 5.86930073194 %
# Phase 6: 0.371731475884 %
# Phase 7: 16.4298166929 %
# Phase 8: 11.887662306 %
# Phase 9: 2.64330315027 %
# Phase 10: 0.22454228112 %
# Phase 11: 0.559529343805 %
# Phase 12: 0.274380500141 %
#
# By weight:
# Phase 1: 53.4044965405 %
# Phase 2: 0.904930175623 %
# Phase 3: 4.67549151787 %
# Phase 4: 3.42006120096 %
# Phase 5: 5.03805945259 %
# Phase 6: 0.514465190562 %
# Phase 7: 17.4671165233 %
# Phase 8: 10.3597039652 %
# Phase 9: 3.13325887129 %
# Phase 10: 0.241535375099 %
# Phase 11: 0.642739400919 %
# Phase 12: 0.198141786088 %
#
#
# OK
