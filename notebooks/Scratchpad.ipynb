# %% [markdown]
# # Rietveld Playground

# %%
# %matplotlib qt
# %load_ext disable_autoscroll
# Out:
# autoscrolling long output is disabled

# %% [markdown]
# ## Docstring: RietveldPhases (class)
#
# Used to group together methods for calculating powder profiles
#   for Rietveld phases.
#
#   `two_theta_0` (float)
#   : $2\theta_0$ is a refinable offset, used
#          to adjust for any miscalibration of detector motor positions when
#          collecting data
#
#   `Bkgd` (np.array)
#   : This array contains the coefficients of a polynomial
#      used to model the profile background
#
#   `K_alpha_2_factor` (float)
#   : The value by which the $K_{\alpha 2}$ peaks are rescaled relative to the primary ($K_{\alpha 1}$) peaks
#      (not refinable at present)
#
#   `delta_theta` (float)
#   : $\Delta\theta$ describes the window over
#      which a given peak profile is evaluated. (In practice it's inefficient
#      to evaluate profile tails many standard deviations away from the peak,
#      so some limit is set hard-coded here.)

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from RietveldPhases import RietveldPhases
from RietveldRefinery import RietveldRefinery

# %%
sys.path.append(os.path.abspath(r"../tests"))
from tst_RietveldPhases import run
run()
# Out:
# Bkgd_0 = 0.0 (-inf, inf)
# Bkgd_1 = 0.0 (-inf, inf)
# Bkgd_2 = 0.0 (-inf, inf)
# two_theta_0 = 0.001 (-2.0, 2.0)
# U = 0.0 (-0.1, 0.1)
# V = 0.0 (-0.1, 0.1)
# W = 0.0006 (-0.1, 0.1)
# Amplitude = 694.692 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (0.0, 0.001)
# U = 0.2 (-0.1, 0.1)
# V = 0.3 (-0.1, 0.1)
# W = 0.0008 (-0.1, 0.1)
# Amplitude = 952.826 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (0.0, 0.001)
# Time elapsed: 9.32299995422
# two_theta_0 = 0.27642 (-2.0, 2.0)
# Amplitude = 601.676 (0.0, inf)
# Amplitude = 0.001 (0.0, inf)
#
# R_wp: 1.90128378198
# R_e: 0.0933947041266
# Goodness-of-Fit: 20.3575117
# Bkgd_0 = 0.0 (-inf, inf)
# Bkgd_1 = 0.0 (-inf, inf)
# Bkgd_2 = 0.0 (-inf, inf)
# two_theta_0 = 0.27642 (-2.0, 2.0)
# U = 0.0 (-0.1, 0.1)
# V = 0.0 (-0.1, 0.1)
# W = 0.0006 (-0.1, 0.1)
# Amplitude = 601.676 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (0.0, 0.001)
# U = 0.2 (-0.1, 0.1)
# V = 0.3 (-0.1, 0.1)
# W = 0.0008 (-0.1, 0.1)
# Amplitude = 0.001 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 0.0 (0.0, 0.001)
# Time elapsed: 17.0999999046
# Bkgd_0 = 2.53587e-07 (-inf, inf)
# Bkgd_1 = 9.77856e-06 (-inf, inf)
# Bkgd_2 = 0.000554304 (-inf, inf)
# two_theta_0 = 0.27642 (-2.0, 2.0)
# U = -2.43177e-05 (-0.1, 0.1)
# V = 2.41388e-05 (-0.1, 0.1)
# W = -5.43263e-06 (-0.1, 0.1)
# Amplitude = 601.676 (0.0, inf)
# eta_0 = 0.5 (0.0, 1.0)
# eta_1 = 1.2088e-08 (0.0, 0.001)
#
# R_wp: 0.99406409048
# R_e: 0.0933947041266
# Goodness-of-Fit: 10.6436879883
# OK
